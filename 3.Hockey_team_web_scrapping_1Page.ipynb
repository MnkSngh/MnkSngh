# %%
from bs4 import BeautifulSoup
import requests
import re
import openpyxl as pl

# %%
excel = pl.Workbook()

# %%
sheet = excel.active

# %%
sheet.title = "Hockey Team Data"

# %%
sheet.append(['Name of the Team','Year of the Team', 
                'No. of matches won', 'No. of lossed', 
                'Golas For the Team','Goals against Team'])

# %%
url = "https://www.scrapethissite.com/pages/forms/"

# %%
source = requests.get(url, verify = False)
# Out:
# C:\Users\mayank.singh27\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.scrapethissite.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
html_text = BeautifulSoup(source.text, 'html.parser')

# %%
html_text
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
Page_heading = html_text.h1.text.strip()

# %%
page_heading = re.sub(r"([\n]|[\n ]{1,})"," ", Page_heading)

# %%
print(page_heading)
# Out:
# Hockey Teams: Forms, Searching and Pagination  25 items

# %%
table = html_text.find_all('tr', class_ = "team")

# %%
table
# Out:
# [<tr class="team">
#  <td class="name">
#                              Boston Bruins
#                          </td>
#  <td class="year">
#                              1990
#                          </td>
#  <td class="wins">
#                              44
#                          </td>
#  <td class="losses">
#                              24
#                          </td>
#  <td class="ot-losses">
#  </td>
#  <td class="pct text-success">
#                              0.55
#                          </td>
#  <td class="gf">
#                              299
#                          </td>
#  <td class="ga">
#                              264
#                          </td>
#  <td class="diff text-success">
#                              35
#                          </td>
#  </tr>,
#  <tr class="team">
#  <td class="name">
#                              Buffalo Sabres
#                          </td>
#  <td class="year">
#                              1990
# ...

# %%
for values in table:
    name =   values.find('td', class_='name').text.strip()
    year =   int(values.find('td', class_ = 'year').text.strip())
    wins =   int(values.find('td', class_ = 'wins').text.strip())
    losses = int(values.find('td', class_ = 'losses').text.strip())
    gf =     int(values.find('td', class_ = 'gf').text.strip())
    ga =     int(values.find('td', class_ = 'ga').text.strip())
#     win_pct = values.find('td',class_= 'pct text-success')
#     win_pct = values.find('td', attrs = {'class':'pct text-success'}).text.strip()
    print(name, year, wins, losses, gf, ga)
    sheet.append([name, year, wins, losses, gf, ga])
# Out:
# Boston Bruins 1990 44 24 299 264
# Buffalo Sabres 1990 31 30 292 278
# Calgary Flames 1990 46 26 344 263
# Chicago Blackhawks 1990 49 23 284 211
# Detroit Red Wings 1990 34 38 273 298
# Edmonton Oilers 1990 37 37 272 272
# Hartford Whalers 1990 31 38 238 276
# Los Angeles Kings 1990 46 24 340 254
# Minnesota North Stars 1990 27 39 256 266
# Montreal Canadiens 1990 39 30 273 249
# New Jersey Devils 1990 32 33 272 264
# New York Islanders 1990 25 45 223 290
# New York Rangers 1990 36 31 297 265
# Philadelphia Flyers 1990 33 37 252 267
# Pittsburgh Penguins 1990 41 33 342 305
# Quebec Nordiques 1990 16 50 236 354
# St. Louis Blues 1990 47 22 310 250
# Toronto Maple Leafs 1990 23 46 241 318
# Vancouver Canucks 1990 28 43 243 315
# Washington Capitals 1990 37 36 258 258
# Winnipeg Jets 1990 26 43 260 288
# Boston Bruins 1991 36 32 270 275
# Buffalo Sabres 1991 31 37 289 299
# Calgary Flames 1991 31 37 296 305
# Chicago Blackhawks 1991 36 29 257 236

# %%
excel.save('Hockey_team_web_scrapping.xlsx')
