# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
url = f"https://www.scrapethissite.com/pages/forms/?page_num=1"

source = requests.get(url, verify = False)

html_text = BeautifulSoup(source.text, 'html.parser')

table = html_text.find_all('tr', class_ = "team")
Data = []
for values in table:
    name =values.find('td', class_='name').text.strip()
    year =int(values.find('td', class_ = 'year').text.strip())
    wins =int(values.find('td', class_ = 'wins').text.strip())
    losses = int(values.find('td', class_ = 'losses').text.strip())
    gf =int(values.find('td', class_ = 'gf').text.strip())
    ga =int(values.find('td', class_ = 'ga').text.strip())
#     win_pct = values.find('td',class_= 'pct text-success')
#     win_pct = values.find('td', attrs = {'class':'pct text-success'}).text.strip()
#         print(name, year, wins, losses, gf, ga)
    Data.append([name, year, wins, losses, gf, ga])
df = pd.DataFrame(Data, columns = ['Name of the Team', 'Year of the Match', 'No of Match Won', 'No of Match Losed', 'Goals for the Team', 'Goals Against the Team'])
(df)
# Out:
# C:\Users\mayank.singh27\AppData\Roaming\Python\Python310\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.scrapethissite.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#          Name of the Team  Year of the Match  No of Match Won  \
# 0           Boston Bruins               1990               44
# 1          Buffalo Sabres               1990               31
# 2          Calgary Flames               1990               46
# 3      Chicago Blackhawks               1990               49
# 4       Detroit Red Wings               1990               34
# 5         Edmonton Oilers               1990               37
# 6        Hartford Whalers               1990               31
# 7       Los Angeles Kings               1990               46
# 8   Minnesota North Stars               1990               27
# 9      Montreal Canadiens               1990               39
# 10      New Jersey Devils               1990               32
# 11     New York Islanders               1990               25
# 12       New York Rangers               1990               36
# 13    Philadelphia Flyers               1990               33
# 14    Pittsburgh Penguins               1990               41
# 15       Quebec Nordiques               1990               16
# 16        St. Louis Blues               1990               47
# 17    Toronto Maple Leafs               1990               23
# 18      Vancouver Canucks               1990               28
# 19    Washington Capitals               1990               37
# 20          Winnipeg Jets               1990               26
# 21          Boston Bruins               1991               36
# 22         Buffalo Sabres               1991               31
# 23         Calgary Flames               1991               31
# 24     Chicago Blackhawks               1991               36
#
#     No of Match Losed  Goals for the Team  Goals Against the Team
# 0                  24                 299                     264
# 1                  30                 292                     278
# 2                  26                 344                     263
# 3                  23                 284                     211
# 4                  38                 273                     298
# 5                  37                 272                     272
# 6                  38                 238                     276
# 7                  24                 340                     254
# 8                  39                 256                     266
# 9                  30                 273                     249
# 10                 33                 272                     264
# 11                 45                 223                     290
# 12                 31                 297                     265
# 13                 37                 252                     267
# 14                 33                 342                     305
# 15                 50                 236                     354
# 16                 22                 310                     250
# 17                 46                 241                     318
# 18                 43                 243                     315
# 19                 36                 258                     258
# 20                 43                 260                     288
# 21                 32                 270                     275
# 22                 37                 289                     299
# 23                 37                 296                     305
# 24                 29                 257                     236

# %%
df.to_csv("6a.Web_scrapping_hockey_team_and Creating Dataframe using Pandas__1Page only.csv")
